# %%
import cv2
import pytesseract
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../csv/Readings.csv')

# %%
img = cv2.imread('../images/file_0.jpg')

# %%
lwr = np.array([0, 0, 0])
upr = np.array([180, 255, 200])
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
msk = cv2.inRange(hsv, lwr, upr)

# %%
cv2.imshow('Preprocessed image', msk)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
krn = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 3))
dlt = cv2.dilate(msk, krn, iterations=5)
res = 255 - cv2.bitwise_and(dlt, msk)

# %%
cv2.imshow('Preprocessed image', res)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
txt = pytesseract.image_to_string(res, config="--psm 6 digits")
print(txt)
# Out:
# -
# 4
#
# . 00 4 4
#
# - .
#
# 1260521 2
# 120 250505 20
#
# 2311599884
#
# -

# %%
import cv2

img = cv2.imread('../images/file_0.jpg')
img = cv2.resize(img, (0, 0), fx=0.5, fy=0.5)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
adaptive = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 85, 11)
cv2.imshow('Preprocessed image', adaptive)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import pytesseract

text = pytesseract.image_to_string(adaptive, config='--psm 6')
print(text)
# Out:
# 4 i? “¢
# eo ee Le,
# : — PROPERTY OF ry) A a :)
# og RB PE CTRICITY COMPANY GE GANA, 2010 | RR. “
# F 3 SF A > oes
# 4M | phase 2Wire Ec eos21 Dame, Be.
# CSG Type HXT20 2500 S0H2 SU25IA Tabrewientn
# “vil (SEES) no 201159988
# } “«j Made in China MS
#
# OM 5 gemae caput NR wag OL ges ee OS

# %%
import os
from easyocr import Reader

def get_file_names(path):
    return [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]

image_files = get_file_names('../images/')

# %%
import os
import re

# Specify the folder path
folder_path = '../images/'

# Get all file names in the folder
file_names = os.listdir(folder_path)

# Sort file names by extracting the number from each file name
sorted_file_names = sorted(file_names, key=lambda x: int(re.search(r'\d+', x).group()))

# Convert to a list of file names (no string formatting)
file_names_list = sorted_file_names

print(file_names_list)
# Out:
# ['file_0.jpg', 'file_1.jpg', 'file_2.jpg', 'file_3.jpg', 'file_4.jpg', 'file_5.jpg', 'file_6.jpg', 'file_7.jpg', 'file_8.jpg', 'file_9.jpg', 'file_10.jpg', 'file_11.jpg', 'file_12.jpg', 'file_13.jpg', 'file_14.jpg', 'file_15.jpg', 'file_16.jpg', 'file_17.jpg', 'file_18.jpg', 'file_19.jpg', 'file_20.jpg', 'file_21.jpg', 'file_22.jpg', 'file_23.jpg', 'file_24.jpg', 'file_25.jpg', 'file_26.jpg', 'file_27.jpg', 'file_28.jpg', 'file_29.jpg', 'file_30.jpg', 'file_31.jpg', 'file_32.jpg', 'file_33.jpg', 'file_34.jpg', 'file_35.jpg', 'file_36.jpg', 'file_37.jpg', 'file_38.jpg', 'file_39.jpg', 'file_40.jpg', 'file_41.jpg', 'file_42.jpg', 'file_43.jpg', 'file_44.jpg', 'file_45.jpg', 'file_46.jpg', 'file_47.jpg', 'file_48.jpg', 'file_49.jpg', 'file_50.jpg', 'file_51.jpg', 'file_52.jpg', 'file_53.jpg', 'file_54.jpg', 'file_55.jpg', 'file_56.jpg', 'file_57.jpg', 'file_58.jpg', 'file_59.jpg', 'file_60.jpg', 'file_61.jpg', 'file_62.jpg', 'file_63.jpg', 'file_64.jpg', 'file_65.jpg', 'file_66.jpg', 'f
# ...

# %%
# !pip install tqdm

# %%
from tqdm import tqdm
import time

for i in tqdm(range(100)):
    time.sleep(0.1)  # Simulating work
# Out:
# 100%|██████████| 100/100 [00:10<00:00,  9.61it/s]

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.6793, 0.2054, 0.4309],
#         [0.3898, 0.3049, 0.9900],
#         [0.4827, 0.8445, 0.8489],
#         [0.7605, 0.4072, 0.4481],
#         [0.5027, 0.6643, 0.1407]])

# %%
# Specify the folder path
folder_path = 'C:/Users/Sasa/Documents/Programiranje/Sotex/images/'

# Get all file names in the folder
file_names = os.listdir(folder_path)

file_names = [folder_path + s for s in file_names]

# Sort file names by extracting the number from each file name
sorted_file_names = sorted(file_names, key=lambda x: int(re.search(r'\d+', x).group()))

# Convert to a list of file names (no string formatting)
image_files = sorted_file_names[:10]
image_files
# Out:
# ['C:/Users/Sasa/Documents/Programiranje/Sotex/images/file_0.jpg',
#  'C:/Users/Sasa/Documents/Programiranje/Sotex/images/file_1.jpg',
#  'C:/Users/Sasa/Documents/Programiranje/Sotex/images/file_2.jpg',
#  'C:/Users/Sasa/Documents/Programiranje/Sotex/images/file_3.jpg',
#  'C:/Users/Sasa/Documents/Programiranje/Sotex/images/file_4.jpg',
#  'C:/Users/Sasa/Documents/Programiranje/Sotex/images/file_5.jpg',
#  'C:/Users/Sasa/Documents/Programiranje/Sotex/images/file_6.jpg',
#  'C:/Users/Sasa/Documents/Programiranje/Sotex/images/file_7.jpg',
#  'C:/Users/Sasa/Documents/Programiranje/Sotex/images/file_8.jpg',
#  'C:/Users/Sasa/Documents/Programiranje/Sotex/images/file_9.jpg']

# %%
# Suppose `actual_values.csv` has two columns: 'Image_ID' and 'Actual_Value'
actual_df = pd.read_csv('../csv/Readings.csv') 
actual_df.head()
# Out:
#                                                  URL  Value
# 0  https://subs-production.s3.us-west-2.amazonaws...   6345
# 1  https://subs-production.s3.us-west-2.amazonaws...   5926
# 2  https://subs-production.s3.us-west-2.amazonaws...   4978
# 3  https://subs-production.s3.us-west-2.amazonaws...   2455
# 4  https://subs-production.s3.us-west-2.amazonaws...    533

# %%
import pandas as pd
import re
import cv2
from easyocr import Reader
import os
from tqdm import tqdm

# Suppose `actual_values.csv` has two columns: 'Image_ID' and 'Actual_Value'
actual_df = pd.read_csv('../csv/Readings.csv')    

# Dictionary to store extracted digits for each image
extracted_data = {}

# Specify the folder path
folder_path = 'C:/Users/Sasa/Documents/Programiranje/Sotex/images/'

# Get all file names in the folder
file_names = os.listdir(folder_path)

file_names = [folder_path + s for s in file_names]

# Sort file names by extracting the number from each file name
sorted_file_names = sorted(file_names, key=lambda x: int(re.search(r'\d+', x).group()))

# Convert to a list of file names (no string formatting)
image_files = sorted_file_names[:20]

reader = Reader(['en'], gpu=False)

# OCR function using EasyOCR (assuming `reader` is initialized as in the previous example)
def extract_digits_from_image(image_path):
    results = reader.readtext(image_path)
    digit_string = ""
    for (bbox, text, prob) in tqdm(results):
        digits = re.findall(r'\d+', text)
        if digits:
            digit_string += ''.join(digits)
    return digit_string

# Extract digits from each image and store in dictionary
for image_file in image_files:
    extracted_data[image_file] = extract_digits_from_image(image_file)

# Convert extracted data to a DataFrame
extracted_df = pd.DataFrame(list(extracted_data.items()), columns=['id', 'Extracted_Value'])

combined_df = pd.concat([actual_df, extracted_df], axis=1)

combined_df.head()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ...
# 100%|██████████| 22/22 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 25/25 [00:00<?, ?it/s]
#                                                  URL  Value  \
# 0  https://subs-production.s3.us-west-2.amazonaws...   6345
# 1  https://subs-production.s3.us-west-2.amazonaws...   5926
# 2  https://subs-production.s3.us-west-2.amazonaws...   4978
# 3  https://subs-production.s3.us-west-2.amazonaws...   2455
# 4  https://subs-production.s3.us-west-2.amazonaws...    533
#
#                                                   id  \
# 0  C:/Users/Sasa/Documents/Programiranje/Sotex/im...
# 1  C:/Users/Sasa/Documents/Programiranje/Sotex/im...
# 2  C:/Users/Sasa/Documents/Programiranje/Sotex/im...
# 3  C:/Users/Sasa/Documents/Programiranje/Sotex/im...
# 4  C:/Users/Sasa/Documents/Programiranje/Sotex/im...
#
#                            Extracted_Value
# 0       2000645070360521220052572291159988
# ...

# %%
combined_df['id'] = combined_df['id'].str.replace('C:/Users/Sasa/Documents/Programiranje/Sotex/images/', '')
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   URL              200 non-null    object
#  1   Value            200 non-null    int64
#  2   id               20 non-null     object
#  3   Extracted_Value  20 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 6.4+ KB

# %%
combined_df.head(20)
# Out:
#                                                   URL  Value           id  \
# 0   https://subs-production.s3.us-west-2.amazonaws...   6345   file_0.jpg
# 1   https://subs-production.s3.us-west-2.amazonaws...   5926   file_1.jpg
# 2   https://subs-production.s3.us-west-2.amazonaws...   4978   file_2.jpg
# 3   https://subs-production.s3.us-west-2.amazonaws...   2455   file_3.jpg
# 4   https://subs-production.s3.us-west-2.amazonaws...    533   file_4.jpg
# 5   https://subs-production.s3.us-west-2.amazonaws...  32811   file_5.jpg
# 6   https://subs-production.s3.us-west-2.amazonaws...   1026   file_6.jpg
# 7   https://subs-production.s3.us-west-2.amazonaws...   2454   file_7.jpg
# 8   https://subs-production.s3.us-west-2.amazonaws...   3980   file_8.jpg
# 9   https://subs-production.s3.us-west-2.amazonaws...   3829   file_9.jpg
# 10  https://subs-production.s3.us-west-2.amazonaws...   7751  file_10.jpg
# 11  https://subs-production.s3.us-west-2.amazonaws...   2995  file_11.jpg
# ...

# %%
combined_df = combined_df.astype(str)
combined_df['Contains'] = combined_df.apply(lambda row: row['Value'] in str(row['Extracted_Value']), axis=1)
combined_df.head(20)
# Out:
#                                                   URL  Value           id  \
# 0   https://subs-production.s3.us-west-2.amazonaws...   6345   file_0.jpg
# 1   https://subs-production.s3.us-west-2.amazonaws...   5926   file_1.jpg
# 2   https://subs-production.s3.us-west-2.amazonaws...   4978   file_2.jpg
# 3   https://subs-production.s3.us-west-2.amazonaws...   2455   file_3.jpg
# 4   https://subs-production.s3.us-west-2.amazonaws...    533   file_4.jpg
# 5   https://subs-production.s3.us-west-2.amazonaws...  32811   file_5.jpg
# 6   https://subs-production.s3.us-west-2.amazonaws...   1026   file_6.jpg
# 7   https://subs-production.s3.us-west-2.amazonaws...   2454   file_7.jpg
# 8   https://subs-production.s3.us-west-2.amazonaws...   3980   file_8.jpg
# 9   https://subs-production.s3.us-west-2.amazonaws...   3829   file_9.jpg
# 10  https://subs-production.s3.us-west-2.amazonaws...   7751  file_10.jpg
# 11  https://subs-production.s3.us-west-2.amazonaws...   2995  file_11.jpg
# ...

# %%
img = cv2.imread('../images/file_4.jpg')

cv2.imshow('Original', img)
cv2.waitKey(0)

# Use the cvtColor() function to grayscale the image
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2.imshow('Grayscale', gray_image)
cv2.waitKey(0)  

# Window shown waits for any key pressing event
cv2.destroyAllWindows()

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('../csv/uncaptured_values_table.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                                URL  Value  \
# 0           0  https://subs-production.s3.us-west-2.amazonaws...   6345
# 1           4  https://subs-production.s3.us-west-2.amazonaws...    533
# 2           5  https://subs-production.s3.us-west-2.amazonaws...  32811
# 3           6  https://subs-production.s3.us-west-2.amazonaws...   1026
# 4           7  https://subs-production.s3.us-west-2.amazonaws...   2454
#
#                     id                    Extracted_Value  Contains
# 0  /content/file_0.jpg  200064500360521220052572291159988     False
# 1  /content/file_4.jpg                    302106804032839     False
# 2  /content/file_5.jpg                                  5     False
# 3  /content/file_6.jpg                         6026123082     False
# 4  /content/file_7.jpg                   0128601110187840     False

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#                                                    URL  Value  \
# 0    https://subs-production.s3.us-west-2.amazonaws...   6345
# 1    https://subs-production.s3.us-west-2.amazonaws...    533
# 2    https://subs-production.s3.us-west-2.amazonaws...  32811
# 3    https://subs-production.s3.us-west-2.amazonaws...   1026
# 4    https://subs-production.s3.us-west-2.amazonaws...   2454
# ..                                                 ...    ...
# 157  https://subs-production.s3.us-west-2.amazonaws...   7683
# 158  https://subs-production.s3.us-west-2.amazonaws...  17106
# 159  https://subs-production.s3.us-west-2.amazonaws...  41028
# 160  https://subs-production.s3.us-west-2.amazonaws...   1772
# 161  https://subs-production.s3.us-west-2.amazonaws...  10429
#
#                         id                       Extracted_Value  Contains
# 0      /content/file_0.jpg     200064500360521220052572291159988     False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   URL              162 non-null    object
#  1   Value            162 non-null    int64
#  2   id               162 non-null    object
#  3   Extracted_Value  135 non-null    object
#  4   Contains         162 non-null    bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 5.3+ KB

# %%
df['Extracted_Value'].isnull().sum()
# Out:
# 27

# %%
import pandas as pd
import requests
import os

# Function to download and rename images
def download_and_rename_images(df, url_column, output_folder):
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Loop through the DataFrame
    for index, row in df.iterrows():
        url = row[url_column]
        
        # Generate a new filename with increment
        new_filename = f"{index}.jpg"  # Start naming from 0
        file_path = os.path.join(output_folder, new_filename)

        # Download the image
        try:
            response = requests.get(url, stream=True)
            response.raise_for_status()  # Check if the request was successful

            # Save the image to the output folder
            with open(file_path, 'wb') as file:
                for chunk in response.iter_content(chunk_size=8192):
                    file.write(chunk)
            print(f"Downloaded {url} as {new_filename}")
        except Exception as e:
            print(f"Failed to download {url}: {e}")

# Sample usage
if __name__ == "__main__":
    # Example: Load your DataFrame (replace this with your actual DataFrame)
    df = pd.read_csv('../csv/Readings 2.csv')

    # Define the URL column name and output folder
    url_column = 'URL'
    output_folder = '../images2'

    # Call the function to download and rename images
    download_and_rename_images(df, url_column, output_folder)
# Out:
# Downloaded https://subs-production.s3.us-west-2.amazonaws.com/1726162297584 as 0.jpg
# Downloaded https://subs-production.s3.us-west-2.amazonaws.com/1726162309162 as 1.jpg
# Downloaded https://subs-production.s3.us-west-2.amazonaws.com/1726162314344 as 2.jpg
# Downloaded https://subs-production.s3.us-west-2.amazonaws.com/1726162316478 as 3.jpg
# Downloaded https://subs-production.s3.us-west-2.amazonaws.com/1726162302101 as 4.jpg
# Downloaded https://subs-production.s3.us-west-2.amazonaws.com/1726162318722 as 5.jpg
# Downloaded https://subs-production.s3.us-west-2.amazonaws.com/1726162320803 as 6.jpg
# Downloaded https://subs-production.s3.us-west-2.amazonaws.com/1726162349829 as 7.jpg
# Downloaded https://subs-production.s3.us-west-2.amazonaws.com/1726162355515 as 8.jpg
# Downloaded https://subs-production.s3.us-west-2.amazonaws.com/1726162323284 as 9.jpg
# Downloaded https://subs-production.s3.us-west-2.amazonaws.com/1726162327745 as 10.jpg
# ...
